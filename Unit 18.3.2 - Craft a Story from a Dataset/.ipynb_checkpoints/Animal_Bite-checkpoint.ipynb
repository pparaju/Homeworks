# %% [markdown]
# In the United States, animal bites are often reported to law enforcement (such as animal control). The main concern with an animal bite is that the animal may be rabid. This dataset includes information on over 9,000 animal bites which occurred near Louisville, Kentucky from 1985 to 2017 and includes information on whether the animal was quarantined after the bite occurred and whether that animal was rabid.

# %%
# ! pip install missingno

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import missingno as msno
import seaborn as sns

# %%
Bites_df = pd.read_csv("Health_AnimalBites.csv")

# %%
Bites_df.head()
# Out:
#              bite_date SpeciesIDDesc BreedIDDesc GenderIDDesc       color  \
# 0  1985-05-05 00:00:00           DOG         NaN       FEMALE  LIG. BROWN
# 1  1986-02-12 00:00:00           DOG         NaN      UNKNOWN   BRO & BLA
# 2  1987-05-07 00:00:00           DOG         NaN      UNKNOWN         NaN
# 3  1988-10-02 00:00:00           DOG         NaN         MALE   BLA & BRO
# 4  1989-08-29 00:00:00           DOG         NaN       FEMALE     BLK-WHT
#
#    vaccination_yrs     vaccination_date victim_zip AdvIssuedYNDesc  \
# 0              1.0  1985-06-20 00:00:00      40229              NO
# 1              NaN                  NaN      40218              NO
# 2              NaN                  NaN      40219              NO
# 3              NaN                  NaN        NaN              NO
# 4              NaN                  NaN        NaN              NO
#
#   WhereBittenIDDesc      quarantine_date DispositionIDDesc head_sent_date  \
# ...

# %% [markdown]
# Attributes of animal bite incidents reported to and investigated by Louisville Metro Department of Public Health and Wellness. Personal/identifying data has been removed. This dataset is a single .csv with the following fields.
#
# bite_date: The date the bite occurred
#
# SpeciesIDDesc: The species of animal that did the biting
#
# BreedIDDesc: Breed (if known)
#
# GenderIDDesc: Gender (of the animal)
#
# color: color of the animal
#
# vaccination_yrs: how many years had passed since the last vaccination
#
# vaccination_date: the date of the last vaccination
#
# victim_zip: the zipcode of the victim
#
# AdvIssuedYNDesc: whether advice was issued
#
# WhereBittenIDDesc: Where on the body the victim was bitten
#
# quarantine_date: whether the animal was quarantined
#
# DispositionIDDesc: whether the animal was released from quarantine
#
# head_sent_date: the date the animal’s head was sent to the lab
#
# release_date: the date the animal was released
#
# ResultsIDDesc: results from lab tests (for rabies)

# %%
Bites_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9003 entries, 0 to 9002
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   bite_date          8686 non-null   object
#  1   SpeciesIDDesc      8885 non-null   object
#  2   BreedIDDesc        3759 non-null   object
#  3   GenderIDDesc       6477 non-null   object
#  4   color              6426 non-null   object
#  5   vaccination_yrs    3738 non-null   float64
#  6   vaccination_date   4115 non-null   object
#  7   victim_zip         7165 non-null   object
#  8   AdvIssuedYNDesc    2565 non-null   object
#  9   WhereBittenIDDesc  8387 non-null   object
#  10  quarantine_date    2020 non-null   object
#  11  DispositionIDDesc  1535 non-null   object
#  12  head_sent_date     395 non-null    object
#  13  release_date       1445 non-null   object
#  14  ResultsIDDesc      1543 non-null   object
# dtypes: float64(1), object(14)
# ...

# %%
msno.matrix(Bites_df)
# Out:
# <Axes: >

# %%
msno.heatmap(Bites_df)
# Out:
# <Axes: >

# %%
# List of columns to convert to datetime
date_columns = ['bite_date', 'vaccination_date', 'quarantine_date', 'head_sent_date', 'release_date']

# Convert the listed columns to datetime
Bites_df[date_columns] = Bites_df[date_columns].apply(pd.to_datetime, errors='coerce')

# %%
Bites_df.describe()
# Out:
#                            bite_date  vaccination_yrs  \
# count                           8685      3738.000000
# mean   2013-09-28 03:33:43.212435200         1.452113
# min              1952-05-28 00:00:00         1.000000
# 25%              2011-11-01 00:00:00         1.000000
# 50%              2013-09-07 00:00:00         1.000000
# 75%              2015-08-16 00:00:00         1.000000
# max              2201-05-01 00:00:00        11.000000
# std                              NaN         0.848416
#
#                     vaccination_date                quarantine_date  \
# count                           4115                           2020
# mean   2013-05-17 03:39:03.718104320  2010-09-08 11:55:00.594059264
# min              1985-06-20 00:00:00            1985-05-05 00:00:00
# 25%              2011-07-05 12:00:00            2010-06-09 00:00:00
# 50%              2013-06-05 00:00:00            2010-11-13 12:00:00
# ...

# %%
start_date = pd.Timestamp('1985-01-01')
end_date = pd.Timestamp('2017-12-31')

Bites_df.loc[(Bites_df['bite_date'] < start_date) | (Bites_df['bite_date'] > end_date), 'bite_date'] = np.nan
Bites_df.loc[(Bites_df['vaccination_date'] > end_date), 'vaccination_date'] = np.nan
Bites_df.loc[(Bites_df['release_date'] > end_date), 'release_date'] = np.nan

# %%
Bites_df = Bites_df.sort_values(by='bite_date').reset_index(drop=True)

# %%
Bites_df.describe()
# Out:
#                            bite_date  vaccination_yrs  \
# count                           8676      3738.000000
# mean   2013-09-05 03:43:44.066390016         1.452113
# min              1985-05-05 00:00:00         1.000000
# 25%              2011-11-01 00:00:00         1.000000
# 50%              2013-09-05 12:00:00         1.000000
# 75%              2015-08-15 00:00:00         1.000000
# max              2017-09-07 00:00:00        11.000000
# std                              NaN         0.848416
#
#                     vaccination_date                quarantine_date  \
# count                           4112                           2020
# mean   2013-05-15 20:14:28.482490368  2010-09-08 11:55:00.594059264
# min              1985-06-20 00:00:00            1985-05-05 00:00:00
# 25%              2011-07-04 06:00:00            2010-06-09 00:00:00
# 50%              2013-06-04 12:00:00            2010-11-13 12:00:00
# ...

# %%
Bites_df.head()
# Out:
#    bite_date SpeciesIDDesc BreedIDDesc GenderIDDesc       color  \
# 0 1985-05-05           DOG         NaN       FEMALE  LIG. BROWN
# 1 1986-02-12           DOG         NaN      UNKNOWN   BRO & BLA
# 2 1987-05-07           DOG         NaN      UNKNOWN         NaN
# 3 1988-10-02           DOG         NaN         MALE   BLA & BRO
# 4 1989-08-29           DOG         NaN       FEMALE     BLK-WHT
#
#    vaccination_yrs vaccination_date victim_zip AdvIssuedYNDesc  \
# 0              1.0       1985-06-20      40229              NO
# 1              NaN              NaT      40218              NO
# 2              NaN              NaT      40219              NO
# 3              NaN              NaT        NaN              NO
# 4              NaN              NaT        NaN              NO
#
#   WhereBittenIDDesc quarantine_date DispositionIDDesc head_sent_date  \
# 0              BODY      1985-05-05           UNKNOWN            NaT
# ...

# %%
sns.set()
Bites_df['year'] = Bites_df['bite_date'].dt.year
# Group by year and count occurrences
year_counts = Bites_df.groupby('year').size()


norm = plt.Normalize(min(year_counts.values), max(year_counts.values))

cmap = plt.get_cmap('coolwarm')

# Get colors based on the normalized values
colors = cmap(norm(year_counts.values))
# Plot bar graph for number of entries by year
plt.figure(figsize=(12, 6))
plt.bar(year_counts.index.astype(str), year_counts.values, color=colors, edgecolor='black')

# Customize tick labels
plt.title('Number of bites by Year')
plt.xlabel('Year')
plt.ylabel('Number of bites')
plt.xticks(rotation=45)  # Rotate labels for readability

plt.tight_layout()
plt.savefig('bites_distribution_by_year.png', format='png', dpi=300)
plt.show()

# %% [markdown]
# https://www.ncei.noaa.gov/access/monitoring/climate-at-a-glance/statewide/time-series/15/tavg/1/0/2010-2017?base_prd=true&begbaseyear=1985&endbaseyear=2017

# %%
temp_df = pd.read_csv("temperature.csv", parse_dates=['Date']).set_index("Date")
temp_df
# Out:
#             Temperature
# Date
# 2010-01-15         29.8
# 2024-02-15         30.6
# 2024-03-15         46.5
# 2024-04-15         59.9
# 2024-05-15         67.3
# ...                 ...
# 2024-08-15         73.1
# 2024-09-15         68.3
# 2024-10-15         59.4
# 2024-11-15         47.1
# 2024-12-15         35.8
#
# [96 rows x 1 columns]

# %%
Bites_df['month'] = Bites_df['bite_date'].dt.month_name()
month_order = ['January', 'February', 'March', 'April', 'May', 'June',
                'July', 'August', 'September', 'October', 'November', 'December']
Bites_df['month'] = pd.Categorical(Bites_df['month'], categories=month_order, ordered=True)

month_counts = Bites_df['month'].value_counts().reindex(month_order)
month_counts
# Out:
# month
# January      556
# February     534
# March        743
# April        845
# May          943
# June         920
# July         893
# August       858
# September    643
# October      632
# November     554
# December     555
# Name: count, dtype: int64

# %%
# Normalize the values to map them to a color scale
norm = plt.Normalize(min(month_counts.values), max(month_counts.values))

cmap = plt.get_cmap('coolwarm')

# Get colors based on the normalized values
colors = cmap(norm(month_counts.values))

# Create the plot and specify the axes
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the bar graph with colored bars on the primary y-axis
bars = ax1.bar(month_counts.index, month_counts.values, color=colors)

# Customize the primary y-axis
ax1.set_title('Distribution of Bites by Month')
ax1.set_xlabel('Month of the Year')
ax1.set_ylabel('Number of Bites')
ax1.set_xticks(month_counts.index)
ax1.set_xticklabels(month_counts.index, rotation=90)

plt.tight_layout()
plt.savefig('bites_distribution_by_month.png', format='png', dpi=300)
plt.show()

# %%
# Extract month while handling NaT (Not a Time) values
Bites_df['day_of_week'] = Bites_df['bite_date'].dt.day_name()
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
Bites_df['day_of_week'] = pd.Categorical(Bites_df['day_of_week'], categories=days_order, ordered=True)

# Group by day_of_week and count occurrences
day_counts = Bites_df['day_of_week'].value_counts().reindex(days_order)
day_counts
# Out:
# day_of_week
# Monday       1194
# Tuesday      1269
# Wednesday    1137
# Thursday     1212
# Friday       1215
# Saturday     1397
# Sunday       1252
# Name: count, dtype: int64

# %%
# Create the plot and specify the axes
fig, ax1 = plt.subplots(figsize=(10, 5))

# Normalize the values to map them to a color scale
norm = plt.Normalize(min(day_counts.values), max(day_counts.values))

cmap = plt.get_cmap('coolwarm')

# Get colors based on the normalized values
colors = cmap(norm(day_counts.values))

# Plot the bar graph with colored bars on the primary y-axis
bars = ax1.bar(day_counts.index, day_counts.values, color=colors)

# Customize the primary y-axis
ax1.set_title('Distribution of Bites by Day of the Week')
ax1.set_xlabel('Day of the Week')
ax1.set_ylabel('Number of Bites')
ax1.set_xticks(day_counts.index)
ax1.set_xticklabels(day_counts.index)

plt.tight_layout()
plt.savefig('bites_distribution_by_day_of_week.png', format='png', dpi=300)
plt.show()

# %%
Bites_df.SpeciesIDDesc.unique()
# Out:
# array(['DOG', 'CAT', 'BAT', 'RACCOON', 'OTHER', nan, 'HORSE', 'RABBIT',
#        'SKUNK', 'FERRET'], dtype=object)

# %%
species_counts = Bites_df.SpeciesIDDesc.value_counts().iloc[:3]
species_counts['OTHERS']=Bites_df.SpeciesIDDesc.value_counts().iloc[3:].sum()
species_counts
# Out:
# SpeciesIDDesc
# DOG       7029
# CAT       1568
# BAT        237
# OTHERS      51
# Name: count, dtype: int64

# %%
fig, ax1 = plt.subplots(figsize=(6, 5))

# Normalize the values to map them to a color scale
norm = plt.Normalize(min(species_counts.values), max(species_counts.values))
cmap = plt.get_cmap('coolwarm')

# Get colors based on the normalized values
colors = cmap(norm(species_counts.values))

# Plot the bar graph with colored bars on the primary y-axis
bars = ax1.bar(species_counts.index, species_counts.values, color=colors)

# Annotate the values on top of each bar
for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval, int(yval), ha='center', va='bottom', fontsize=10)

# Customize the primary y-axis
ax1.set_title('Distribution of Bites by Species')
ax1.set_xlabel('Species type')
ax1.set_ylabel('Number of Bites')
ax1.set_xticks(species_counts.index)
ax1.set_xticklabels(species_counts.index)

plt.tight_layout()
plt.savefig('bites_distribution_by_species.png', format='png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Get the value counts and identify the top 10 breeds
breed_counts = Bites_df['BreedIDDesc'].value_counts()
top_10_breeds = breed_counts[:15]
# Normalize the values to map them to a color scale
norm = plt.Normalize(min(top_10_breeds.values), max(top_10_breeds.values))
cmap = plt.get_cmap('coolwarm')

# Get colors based on the normalized values
colors = cmap(norm(top_10_breeds.values))

# Plot the histogram
top_10_breeds.plot(kind='bar', color=colors, edgecolor='black')
plt.title('Ditribution of bites by Breed (top 15)')
plt.xlabel('Breed of the animal')
plt.ylabel('Recorded Bite Counts')
plt.xticks(rotation=90)
plt.savefig('bites_distribution_by_breed.png', format='png', dpi=300)
plt.show()

# %%
gender_count = pd.DataFrame(Bites_df['GenderIDDesc'].value_counts()).rename(columns={"GenderIDDesc": "Gender","count":"Total"})
gender_count["Dog"]= Bites_df[Bites_df['SpeciesIDDesc']=="DOG"]['GenderIDDesc'].value_counts().values
gender_count["Cat"]= Bites_df[Bites_df['SpeciesIDDesc']=="CAT"]['GenderIDDesc'].value_counts().values
gender_count
# Out:
#               Total   Dog  Cat
# GenderIDDesc
# MALE           3832  3307  522
# FEMALE         2016  1601  411
# UNKNOWN         629   464  144

# %%
# Create subplots for 3 pie charts (one for each column)
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot pie chart for 'Total'
axs[0].pie(gender_count['Total'], labels=gender_count.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral'])
axs[0].set_title('Total')

# Plot pie chart for 'Dog'
axs[1].pie(gender_count['Dog'], labels=gender_count.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral'])
axs[1].set_title('Dog')

# Plot pie chart for 'Cat'
axs[2].pie(gender_count['Cat'], labels=gender_count.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral'])
axs[2].set_title('Cat')

plt.tight_layout()
plt.show()

# %%
# Colors for slices
colors = ['skyblue', 'lightgreen', 'lightcoral']

# Create a single plot
fig, ax = plt.subplots(figsize=(8, 8))

# Plot the outermost donut (Total)
ax.pie(gender_count['Dog'], labels=gender_count.index, autopct='%1.1f%%', 
       startangle=90, pctdistance=0.9, colors=colors, radius=1)
ax.text(0, -0.9, 'Dog', horizontalalignment='center', fontsize=18, color='red')

# Draw a white circle in the center for the donut look
centre_circle = plt.Circle((0, 0), 0.8, fc='white')
fig.gca().add_artist(centre_circle)

# Plot the middle donut (Dog)
ax.pie(gender_count['Total'], labels=None, startangle=90, autopct='%1.1f%%', 
       pctdistance=0.85, colors=colors, radius=0.75)
ax.text(0, -0.67, 'Total', horizontalalignment='center', fontsize=18, color='red')

# Draw another white circle in the center for the donut look
centre_circle = plt.Circle((0, 0), 0.55, fc='white')
fig.gca().add_artist(centre_circle)

# Plot the innermost donut (Cat)
ax.pie(gender_count['Cat'], labels=None, startangle=90, autopct='%1.1f%%', 
       pctdistance=0.8, colors=colors, radius=0.5)
ax.text(0, -0.42, 'Cat', horizontalalignment='center', fontsize=18, color='red')

# Draw another white circle for the final inner layer of the donut
inner_circle = plt.Circle((0, 0), 0.3, fc='white')
fig.gca().add_artist(inner_circle)

# Set the title and display the plot
ax.set_title("Concentric Donut Charts for Gender Bites ( Dog,Total, Cat)")
plt.tight_layout()
plt.savefig('bites_pie_gender1.png', format='png', dpi=300)
plt.show()

# %%
# Colors for slices
colors = ['skyblue', 'lightgray', 'lightgray']

# Create a single plot
fig, ax = plt.subplots(figsize=(8, 8))

# Plot the outermost donut (Total)
ax.pie(gender_count['Dog'], labels=gender_count.index, autopct='%1.1f%%', 
       startangle=90, pctdistance=0.9, colors=colors, radius=1)
ax.text(0, -0.9, 'Dog', horizontalalignment='center', fontsize=18, color='red')

# Draw a white circle in the center for the donut look
centre_circle = plt.Circle((0, 0), 0.8, fc='white')
fig.gca().add_artist(centre_circle)

# Plot the middle donut (Dog)
ax.pie(gender_count['Total'], labels=None, startangle=90, autopct='%1.1f%%', 
       pctdistance=0.85, colors=colors, radius=0.75)
ax.text(0, -0.67, 'Total', horizontalalignment='center', fontsize=18, color='red')

# Draw another white circle in the center for the donut look
centre_circle = plt.Circle((0, 0), 0.55, fc='white')
fig.gca().add_artist(centre_circle)

# Plot the innermost donut (Cat)
ax.pie(gender_count['Cat'], labels=None, startangle=90, autopct='%1.1f%%', 
       pctdistance=0.8, colors=colors, radius=0.5)
ax.text(0, -0.42, 'Cat', horizontalalignment='center', fontsize=18, color='red')

# Draw another white circle for the final inner layer of the donut
inner_circle = plt.Circle((0, 0), 0.3, fc='white')
fig.gca().add_artist(inner_circle)

# Set the title and display the plot
ax.set_title("Concentric Donut Charts for Gender Bites ( Dog,Total, Cat)")
plt.tight_layout()
plt.savefig('bites_pie_gender2.png', format='png', dpi=300)
plt.show()

# %%
# Colors for slices
colors = ['lightgray', 'lightgreen', 'lightgray']

# Create a single plot
fig, ax = plt.subplots(figsize=(8, 8))

# Plot the outermost donut (Total)
ax.pie(gender_count['Dog'], labels=gender_count.index, autopct='%1.1f%%', 
       startangle=90, pctdistance=0.9, colors=colors, radius=1)
ax.text(0, -0.9, 'Dog', horizontalalignment='center', fontsize=18, color='red')

# Draw a white circle in the center for the donut look
centre_circle = plt.Circle((0, 0), 0.8, fc='white')
fig.gca().add_artist(centre_circle)

# Plot the middle donut (Dog)
ax.pie(gender_count['Total'], labels=None, startangle=90, autopct='%1.1f%%', 
       pctdistance=0.85, colors=colors, radius=0.75)
ax.text(0, -0.67, 'Total', horizontalalignment='center', fontsize=18, color='red')

# Draw another white circle in the center for the donut look
centre_circle = plt.Circle((0, 0), 0.55, fc='white')
fig.gca().add_artist(centre_circle)

# Plot the innermost donut (Cat)
ax.pie(gender_count['Cat'], labels=None, startangle=90, autopct='%1.1f%%', 
       pctdistance=0.8, colors=colors, radius=0.5)
ax.text(0, -0.42, 'Cat', horizontalalignment='center', fontsize=18, color='red')

# Draw another white circle for the final inner layer of the donut
inner_circle = plt.Circle((0, 0), 0.3, fc='white')
fig.gca().add_artist(inner_circle)

# Set the title and display the plot
ax.set_title("Concentric Donut Charts for Gender Bites ( Dog,Total, Cat)")
plt.tight_layout()
plt.savefig('bites_pie_gender3.png', format='png', dpi=300)
plt.show()

# %%
# Colors for slices
colors = ['lightgray', 'lightgray', 'lightcoral']

# Create a single plot
fig, ax = plt.subplots(figsize=(8, 8))

# Plot the outermost donut (Total)
ax.pie(gender_count['Dog'], labels=gender_count.index, autopct='%1.1f%%', 
       startangle=90, pctdistance=0.9, colors=colors, radius=1)
ax.text(0, -0.9, 'Dog', horizontalalignment='center', fontsize=18, color='red')

# Draw a white circle in the center for the donut look
centre_circle = plt.Circle((0, 0), 0.8, fc='white')
fig.gca().add_artist(centre_circle)

# Plot the middle donut (Dog)
ax.pie(gender_count['Total'], labels=None, startangle=90, autopct='%1.1f%%', 
       pctdistance=0.85, colors=colors, radius=0.75)
ax.text(0, -0.67, 'Total', horizontalalignment='center', fontsize=18, color='red')

# Draw another white circle in the center for the donut look
centre_circle = plt.Circle((0, 0), 0.55, fc='white')
fig.gca().add_artist(centre_circle)

# Plot the innermost donut (Cat)
ax.pie(gender_count['Cat'], labels=None, startangle=90, autopct='%1.1f%%', 
       pctdistance=0.8, colors=colors, radius=0.5)
ax.text(0, -0.42, 'Cat', horizontalalignment='center', fontsize=18, color='red')

# Draw another white circle for the final inner layer of the donut
inner_circle = plt.Circle((0, 0), 0.3, fc='white')
fig.gca().add_artist(inner_circle)

# Set the title and display the plot
ax.set_title("Concentric Donut Charts for Gender Bites ( Dog,Total, Cat)")
plt.tight_layout()
plt.savefig('bites_pie_gender4.png', format='png', dpi=300)
plt.show()

# %%
Bites_by_zip = pd.DataFrame( Bites_df['victim_zip'].value_counts()).reset_index()
Bites_by_zip = Bites_by_zip.rename(columns={"victim_zip": "zip_code"})
Bites_by_zip.head()
# Out:
#   zip_code  count
# 0    40272    376
# 1    40291    368
# 2    40216    362
# 3    40215    356
# 4    40214    348

# %%
population_df = pd.read_csv("population.csv")
population_df = population_df.iloc[:,:2]
# Rename the columns
population_df = population_df.rename(columns={"ZipCode": "zip_code"})
population_df['zip_code'] = population_df['zip_code'].astype(str)
# Remove commas and strip whitespace, then convert the Population column to integers
population_df['Population'] = population_df['Population'].str.replace(',', '').str.strip().astype(int)

population_df.head()
# Out:
#   zip_code  Population
# 0    40214       47343
# 1    40216       43454
# 2    40299       39745
# 3    40219       38626
# 4    40272       37829

# %%
merged_df = pd.merge(Bites_by_zip, population_df, on="zip_code", how="left")
merged_df = merged_df[merged_df["count"]>50]
merged_df.head()
# Out:
#   zip_code  count  Population
# 0    40272    376     37829.0
# 1    40291    368     37772.0
# 2    40216    362     43454.0
# 3    40215    356     22485.0
# 4    40214    348     47343.0

# %%
plt.figure(figsize=(10, 6))

# Create a scatter plot with a regression line
sns.regplot(x='Population', y='count', data=merged_df, 
            scatter_kws={'color': 'blue', 'alpha': 0.7}, 
            line_kws={'color': 'red'})

# Add annotations for each point
for i in range(len(merged_df)):
    plt.annotate(merged_df['zip_code'][i], 
                 (merged_df['Population'][i], merged_df['count'][i]), 
                 textcoords="offset points", 
                 xytext=(0,5), 
                 ha='center')

# Customize the plot
plt.title('Scatter Plot of Population vs. Count with Fit Line')
plt.xlabel('Population')
plt.ylabel('Count')
plt.grid(True)
plt.savefig('bite_count_population2.png', format='png', dpi=300)
plt.show()

# %%
merged_df[["count", "Population"]].corr()
# Out:
#                count  Population
# count       1.000000    0.892875
# Population  0.892875    1.000000

# %%
# Create the figure and axis objects
fig, ax1 = plt.subplots(figsize=(12, 6))

norm = plt.Normalize(min(merged_df['count']), max(merged_df['count']))
cmap = plt.get_cmap('coolwarm')

# Get colors based on the normalized values
colors = cmap(norm(merged_df['count']))

# Plot the bar graph for bite counts on the primary y-axis
bars = ax1.bar(merged_df['zip_code'], merged_df['count'], color=colors)

# Customize the primary y-axis
ax1.set_xlabel('Zip Code')
ax1.set_ylabel('Bite Count')
ax1.set_title('Bite Count (>50) distribution by zip code')
ax1.tick_params(axis='x', rotation=90)  # Rotate x-axis labels by 90 degrees


# Adjust the layout to avoid overlap
plt.tight_layout()
plt.savefig('bites_distribution_by_zip.png', format='png', dpi=300)

# Show the plot
plt.show()

# %%
# Create the figure and axis objects
fig, ax1 = plt.subplots(figsize=(12, 6))

norm = plt.Normalize(min(merged_df['count']), max(merged_df['count']))
cmap = plt.get_cmap('coolwarm')

# Get colors based on the normalized values
colors = cmap(norm(merged_df['count']))

# Plot the bar graph for bite counts on the primary y-axis
bars = ax1.bar(merged_df['zip_code'], merged_df['count'], color=colors)

# Customize the primary y-axis
ax1.set_xlabel('Zip Code')
ax1.set_ylabel('Bite Count')
ax1.set_title('Bite Count (>50) and Population by Zip Code')
ax1.tick_params(axis='x', rotation=90)  # Rotate x-axis labels by 90 degrees

# Create a secondary y-axis for population
ax2 = ax1.twinx()

# Plot the population data with a line plot and markers (Δ shape for markers)
ax2.plot(merged_df['zip_code'], merged_df['Population'], marker='D', linestyle='-',linewidth=2, color='black')

# Customize the secondary y-axis
ax2.set_ylabel('Population', color='black')
ax2.tick_params(axis='y', labelcolor='black')

# Adjust the layout to avoid overlap
plt.tight_layout()
plt.savefig('bites_distribution_by_zip1.png', format='png', dpi=300)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 5))
Bites_df['WhereBittenIDDesc'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Histogram of SpeciesIDDesc')
plt.xlabel('Species')
plt.ylabel('Recorded bite counts')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
Bites_df[Bites_df['WhereBittenIDDesc']=="HEAD"]['AdvIssuedYNDesc'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Histogram of SpeciesIDDesc')
plt.xlabel('Species')
plt.ylabel('Recorded bite counts')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
Bites_df['DispositionIDDesc'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Histogram of SpeciesIDDesc')
plt.xlabel('Species')
plt.ylabel('Recorded bite counts')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
Bites_df['ResultsIDDesc'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Histogram of SpeciesIDDesc')
plt.xlabel('Species')
plt.ylabel('Recorded bite counts')
plt.xticks(rotation=45)
plt.show()

# %%
species_df = pd.DataFrame(Bites_df["SpeciesIDDesc"].value_counts()).reset_index().rename(columns={"SpeciesIDDesc": "Species","count":"Total"})

vaccinated = pd.DataFrame(Bites_df[(Bites_df['vaccination_yrs'] > 0)]["SpeciesIDDesc"].value_counts()).reset_index().rename(columns={"SpeciesIDDesc": "Species","count":"Vaccinated"})
species_df = pd.merge(species_df,vaccinated, on= "Species", how = "left")

unvaccinated = pd.DataFrame(Bites_df[~(Bites_df['vaccination_yrs'] > 0)]["SpeciesIDDesc"].value_counts()).reset_index().rename(columns={"SpeciesIDDesc": "Species","count":"Unvaccinated"})
species_df = pd.merge(species_df,unvaccinated, on= "Species", how = "left")

sent_for_test = pd.DataFrame(Bites_df[((Bites_df['ResultsIDDesc'] == "NEGATIVE") | (Bites_df['ResultsIDDesc'] == "POSITIVE"))]["SpeciesIDDesc"].value_counts()).reset_index().rename(columns={"SpeciesIDDesc": "Species","count":"sent_for_test"})
species_df = pd.merge(species_df,sent_for_test, on= "Species", how = "left")

vaccinated_and_tested_positive = pd.DataFrame(Bites_df[((Bites_df['vaccination_yrs'] > 0)&(Bites_df['ResultsIDDesc'] == "POSITIVE" ))]["SpeciesIDDesc"].value_counts()).reset_index().rename(columns={"SpeciesIDDesc": "Species","count":"vaccinated_and_ntested_positive"})
species_df = pd.merge(species_df,vaccinated_and_tested_positive, on= "Species", how = "left")

vaccinated_and_tested_negative = pd.DataFrame(Bites_df[((Bites_df['vaccination_yrs'] > 0)&(Bites_df['ResultsIDDesc'] == "NEGATIVE" ))]["SpeciesIDDesc"].value_counts()).reset_index().rename(columns={"SpeciesIDDesc": "Species","count":"Vaccinated_and_tested_negative"})
species_df = pd.merge(species_df,vaccinated_and_tested_negative, on= "Species", how = "left")

unvaccinated_and_tested_positive = pd.DataFrame(Bites_df[(~(Bites_df['vaccination_yrs'] > 0)& (Bites_df['ResultsIDDesc'] == "POSITIVE"))]["SpeciesIDDesc"].value_counts()).reset_index().rename(columns={"SpeciesIDDesc": "Species","count":"Unvaccinated_and_tested_positive"})
species_df = pd.merge(species_df,unvaccinated_and_tested_positive, on= "Species", how = "left")

unvaccinated_and_tested_negative = pd.DataFrame(Bites_df[(~(Bites_df['vaccination_yrs'] > 0)&(Bites_df['ResultsIDDesc'] == "NEGATIVE" ))]["SpeciesIDDesc"].value_counts()).reset_index().rename(columns={"SpeciesIDDesc": "Species","count":"Unvaccinated_but_tested_negative"})
species_df = pd.merge(species_df,unvaccinated_and_tested_negative, on= "Species", how = "left")
species_df = species_df.fillna(0)
species_df = species_df.set_index("Species")
species_df
species_df.to_excel('species_analysis.xlsx',)

# %%
Bites_df
# Out:
# Index(['bite_date', 'SpeciesIDDesc', 'BreedIDDesc', 'GenderIDDesc', 'color',
#        'vaccination_yrs', 'vaccination_date', 'victim_zip', 'AdvIssuedYNDesc',
#        'WhereBittenIDDesc', 'quarantine_date', 'DispositionIDDesc',
#        'head_sent_date', 'release_date', 'ResultsIDDesc', 'year', 'month',
#        'day_of_week'],
#       dtype='object')

# %%
Bites_df[((Bites_df['vaccination_yrs'] > 0)&((Bites_df['ResultsIDDesc'] == "NEGATIVE") | (Bites_df['ResultsIDDesc'] == "POSITIVE")))]["SpeciesIDDesc"].value_counts()
# Out:
# SpeciesIDDesc
# DOG    2
# Name: count, dtype: int64
